# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import mpl_interactions as pli

# %%
import fastcat as fc

# %% [markdown]
# ### Write a small nrrd brain volume
#
# Nrrd is a common 3d image format. I use 3D slicer to manipulate dicom images and then export them as nrrd, nrrd is the default image export file type.

# %%
# This is the file that contains the conversion values from HU to density and material
conversion_file = 'schneider_material_conv.txt'

density_map, binary_file, density_file  = fc.utils.nrrd_to_mhd('data/smaller_volume_CNS_CT.nrrd',conversion_file=conversion_file, return_arrays=True)
# Out:
# [2024-03-28 14:53:07,931] {utils.py:575} INFO - The spacing is [[ 0.        0.        1.25    ]
#  [ 0.       -0.761719  0.      ]
#  [-0.761719  0.        0.      ]]
# [2024-03-28 14:53:07,931] {utils.py:576} INFO - The origin is [-44.61909866 156.1519928  135.56799316]
# [2024-03-28 14:53:07,932] {utils.py:577} INFO - The shape is (9, 300, 345)
# [2024-03-28 14:53:07,952] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:07,956] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight1 atten to file in data/mu_over_rho/SchneiderMaterialsWeight1.csv
# [2024-03-28 14:53:07,956] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:07,959] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight2 atten to file in data/mu_over_rho/SchneiderMaterialsWeight2.csv
# [2024-03-28 14:53:07,960] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:07,963] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight3 atten to file in data/mu_over_rho/SchneiderMaterialsWeight3.csv
# [2024-03-28 14:53:07,964] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:07,967] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight4 atten to file in data/mu_over_rho/SchneiderMaterialsWeight4.csv
# [2024-03-28 14:53:07,967] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:07,970] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight5 atten to file in data/mu_over_rho/SchneiderMaterialsWeight5.csv
# [2024-03-28 14:53:07,971] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:07,974] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight6 atten to file in data/mu_over_rho/SchneiderMaterialsWeight6.csv
# [2024-03-28 14:53:07,975] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:07,980] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight7 atten to file in data/mu_over_rho/SchneiderMaterialsWeight7.csv
# [2024-03-28 14:53:07,983] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:07,990] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight8 atten to file in data/mu_over_rho/SchneiderMaterialsWeight8.csv
# [2024-03-28 14:53:07,991] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:07,995] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight9 atten to file in data/mu_over_rho/SchneiderMaterialsWeight9.csv
# [2024-03-28 14:53:07,996] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:08,001] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight10 atten to file in data/mu_over_rho/SchneiderMaterialsWeight10.csv
# [2024-03-28 14:53:08,001] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:08,006] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight11 atten to file in data/mu_over_rho/SchneiderMaterialsWeight11.csv
# [2024-03-28 14:53:08,006] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:08,010] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight12 atten to file in data/mu_over_rho/SchneiderMaterialsWeight12.csv
# [2024-03-28 14:53:08,011] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:08,015] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight13 atten to file in data/mu_over_rho/SchneiderMaterialsWeight13.csv
# [2024-03-28 14:53:08,016] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:08,020] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight14 atten to file in data/mu_over_rho/SchneiderMaterialsWeight14.csv
# [2024-03-28 14:53:08,021] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:08,025] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight15 atten to file in data/mu_over_rho/SchneiderMaterialsWeight15.csv
# [2024-03-28 14:53:08,026] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:08,029] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight16 atten to file in data/mu_over_rho/SchneiderMaterialsWeight16.csv
# [2024-03-28 14:53:08,030] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:08,034] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight17 atten to file in data/mu_over_rho/SchneiderMaterialsWeight17.csv
# [2024-03-28 14:53:08,034] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:08,037] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight18 atten to file in data/mu_over_rho/SchneiderMaterialsWeight18.csv
# [2024-03-28 14:53:08,038] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:08,044] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight19 atten to file in data/mu_over_rho/SchneiderMaterialsWeight19.csv
# [2024-03-28 14:53:08,045] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:08,050] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight20 atten to file in data/mu_over_rho/SchneiderMaterialsWeight20.csv
# [2024-03-28 14:53:08,051] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:08,056] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight21 atten to file in data/mu_over_rho/SchneiderMaterialsWeight21.csv
# [2024-03-28 14:53:08,056] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:08,060] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight22 atten to file in data/mu_over_rho/SchneiderMaterialsWeight22.csv
# [2024-03-28 14:53:08,061] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:08,065] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight23 atten to file in data/mu_over_rho/SchneiderMaterialsWeight23.csv
# [2024-03-28 14:53:08,066] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:08,069] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight24 atten to file in data/mu_over_rho/SchneiderMaterialsWeight24.csv
# [2024-03-28 14:53:08,070] {utils.py:368} INFO - Loading density data from file
# [2024-03-28 14:53:08,074] {utils.py:696} INFO -     Saved SchneiderMaterialsWeight25 atten to file in data/mu_over_rho/SchneiderMaterialsWeight25.csv
# SchneiderMaterialsWeight1: d=0.0388 g/cm3 ; n=13;
# SchneiderMaterialsWeight2: d=0.4695 g/cm3 ; n=13;
# SchneiderMaterialsWeight3: d=0.8749 g/cm3 ; n=13;
# SchneiderMaterialsWeight4: d=0.9122 g/cm3 ; n=13;
# SchneiderMaterialsWeight5: d=0.9467 g/cm3 ; n=13;
# SchneiderMaterialsWeight6: d=0.9799 g/cm3 ; n=13;
# SchneiderMaterialsWeight7: d=1.0039 g/cm3 ; n=13;
# SchneiderMaterialsWeight8: d=1.0408 g/cm3 ; n=13;
# SchneiderMaterialsWeight9: d=1.0785 g/cm3 ; n=13;
# SchneiderMaterialsWeight10: d=1.1083 g/cm3 ; n=13;
# SchneiderMaterialsWeight11: d=1.1658 g/cm3 ; n=13;
# SchneiderMaterialsWeight12: d=1.2312 g/cm3 ; n=13;
# SchneiderMaterialsWeight13: d=1.2963 g/cm3 ; n=13;
# SchneiderMaterialsWeight14: d=1.3604 g/cm3 ; n=13;
# SchneiderMaterialsWeight15: d=1.4256 g/cm3 ; n=13;
# SchneiderMaterialsWeight16: d=1.4916 g/cm3 ; n=13;
# SchneiderMaterialsWeight17: d=1.5590 g/cm3 ; n=13;
# SchneiderMaterialsWeight18: d=1.6245 g/cm3 ; n=13;
# SchneiderMaterialsWeight19: d=1.6888 g/cm3 ; n=13;
# SchneiderMaterialsWeight20: d=1.7561 g/cm3 ; n=13;
# SchneiderMaterialsWeight21: d=1.8213 g/cm3 ; n=13;
# SchneiderMaterialsWeight22: d=1.8873 g/cm3 ; n=13;
# SchneiderMaterialsWeight23: d=1.9540 g/cm3 ; n=13;
# SchneiderMaterialsWeight24: d=2.4229 g/cm3 ; n=13;
# SchneiderMaterialsWeight25: d=4.5525 g/cm3 ; n=13;
# /home/jericho/Software/fastcat/fastcat/spectrum.py:108: RuntimeWarning: divide by zero encountered in log
#   log_y = np.log(yy)

# %% [markdown]
# Plot the density and the materials

# %%
plt.figure()
plt.subplot(121)
cont = pli.hyperslicer(binary_file)
plt.title('Material #')
# These correspond to the material numbers in the conversion file
plt.colorbar()
plt.axis('off')
plt.subplot(122)
cont2 = pli.hyperslicer(density_file,controls=cont)
plt.title('Density [$g/cm^3$]')
plt.colorbar()
plt.axis('off')
# Out:
# VBox(children=(HBox(children=(IntSlider(value=0, description='axis0', max=8, readout=False), Label(value='0'))…
# (-0.5, 344.5, 299.5, -0.5)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot(np.arange(-1000,2996),density_map)
plt.xlabel('Hounsfield Units')
plt.ylabel('Density [$g/cm^3$]')
plt.title('Density HU conversion')
# Out:
# Text(0.5, 1.0, 'Density HU conversion')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
