# %%
# %pylab nbagg
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
sys.path.insert(0,'../xpecgen')

import xpecgen as xg

spectrum_file = 'Al_spectrum_25'

det = 'CuGOS-784-micrometer'

angles = np.linspace(0,2*pi,180)

phantom1 = xg.Catphan_515()

# %%
s = xg.Spectrum()

s.load(spectrum_file)

kernel = xg.Kernel(s, det)

phantom1.return_projs(kernel,s,angles,tigre_works=True,mgy=0)
# Out:
# ratio is None number of photons 0.005883501953124999

# %%
fig = plt.figure()

phantom1.plot_projs(fig)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
phantom.return_projs(kernel,s,angles,tigre_works=False,mgy=0)
# Out:
# ratio is None number of photons 0.005883501953124999

# %%
fig = plt.figure()

phantom.plot_projs(fig)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
phantom.proj.shape
# Out:
# (180, 10, 512)

# %%
plt.figure()
plt.imshow(100*(phantom.proj[:,0,110:400] - phantom1.proj[:,0,110:400])/phantom1.proj[:,0,110:400])
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
phantom.reconstruct(algo='FDK',filt=None)
# Out:
# WARNING: Tigre failed during recon using Astra

# %%
plt.figure()
plt.imshow(phantom.img[1,:,:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
phantom.vol_geom
# Out:
# {'option': {'WindowMinX': -256.0,
#   'WindowMaxX': 256.0,
#   'WindowMinY': -256.0,
#   'WindowMaxY': 256.0},
#  'GridRowCount': 512,
#  'GridColCount': 512}

# %%
phantom.sin_id
# Out:
# 249

# %%
print(phantom.geomet)
# Out:
# TIGRE parameters
# -----
# Geometry parameters
# Distance from source to detector (DSD) = 1520 mm
# Distance from source to origin (DSO)= 1000 mm
# -----
# Detector parameters
# Number of pixels (nDetector) = [ 64 512]
# Size of each pixel (dDetector) = [0.784 0.784] mm
# Total size of the detector (sDetector) = [ 50.176 401.408] mm
# -----
# Image parameters
# Number of voxels (nVoxel) = [ 10 512 512]
# Total size of the image (sVoxel) = [160 160 160] mm
# Size of each voxel (dVoxel) = [16.      0.3125  0.3125] mm
# -----
# Offset correction parameters
# Offset of image from origin (offOrigin) = [0 0 0] mm
# Offset of detector (offDetector) = [0 0] mm
# -----
# Auxillary parameters
# Samples per pixel of forward projection (accuracy) = 0.5
# -----
# Rotation of the Detector (rotDetector) = [0 0 0] rad
