# %%
# %pylab nbagg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
import os
import tigre
from scipy.signal import fftconvolve

sys.path.insert(0,'../fastcat')

import fastcat as fc
from scipy.optimize import minimize, curve_fit

# %%
fc.__version__
# Out:
# '1.3.0'

# %%
from fastcat import fastcat as fc

# %%
fc.__version__
# Out:
# '1.3.0'

# %%
from fastcat import fastcat as fc

# %%
fc.Catphan_515()

# %%
fc.data_path
# Out:
# '/home/xcite/anaconda3/lib/python3.7/site-packages/fastcat-1.3.0-py3.7.egg/fastcat/data'

# %%
# !ls /home/xcite/anaconda3/lib/python3.7/site-packages/fastcat-1.3.0-py3.7.egg/fastcat/data
# Out:
# ls: cannot access '/home/xcite/anaconda3/lib/python3.7/site-packages/fastcat-1.3.0-py3.7.egg/fastcat/data': No such file or directory
