# %%
# %pylab nbagg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import fastcat as cat

# %%
cat
# Out:
# <module 'fastcat' from '/home/xcite/anaconda3/lib/python3.7/site-packages/fastcat-1.3.0-py3.7.egg/fastcat/__init__.py'>
