# %%
# %pylab widget

from scipy.optimize import minimize
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tot = (8+ 6*5 + 8*2)

def fun_zeff(a):
    
    x = 2.94
    tot = (a[0]*1 + a[1]*6 + a[2]*8)
    
    return np.abs((((a[0]*1)/(tot)*1**x + (a[1]*6)/tot*6**x + (a[2]*8)/tot*8**x)**(1/x) - 6.95))

res = minimize(fun_zeff,[8,5,2],bounds=((0,20),(0,20),(0,20)))

nums  = []
reses = []
x = 2.94

for ii in range(21):
    for jj in range(1,10):
        for kk in range(0,10):
            for ll in range(0,4):

                tot = (ii*1 + jj*6 + kk*15 + ll*20)

                reses.append(np.abs((((ii*1)/(tot)*1**x + (jj*6)/tot*6**x + (kk*15)/tot*15**x + (ll*20)/tot*20**x)**(1/x) - 6.95)))
                nums.append([ii,jj,kk,ll])

# %%
a = [0.0634, 0.6156, 0.1993, 0.1217]

x = 2.94
tot = (a[0]*1 + a[1]*6 + a[2]*8 + a[3]*17)
    
(((a[0]*1)/(tot)*1**x + (a[1]*6)/tot*6**x + (a[2]*8)/tot*8**x + (a[3]*17/tot*17**x)))**(1/x)
# Out:
# 11.605639060919712

# %%
# print(sorted(reses)[1:100],np.argmin(reses))

for ii in range(100):
#     print(nums[np.argmin(reses)])
    reses[np.argmin(reses)] = 100

np.argmin(np.abs(np.array(reses) - .0021585833941522026))

vals =  [2.00E-02,1.41E+00,
2.10E-02,1.24E+00,
2.20E-02,1.11E+00,
2.30E-02,9.93E-01,
2.40E-02,8.97E-01,
2.50E-02,8.16E-01,
2.60E-02,7.47E-01,
2.70E-02,6.87E-01,
2.80E-02,6.36E-01,
2.90E-02,5.91E-01,
3.00E-02,5.52E-01,
3.10E-02,5.18E-01,
3.20E-02,4.88E-01,
3.30E-02,4.61E-01,
3.40E-02,4.37E-01,
3.50E-02,4.16E-01,
3.60E-02,3.97E-01,
3.70E-02,3.80E-01,
3.80E-02,3.65E-01,
3.90E-02,3.51E-01,
4.00E-02,3.38E-01,
4.10E-02,3.27E-01,
4.20E-02,3.16E-01,
4.30E-02,3.07E-01,
4.40E-02,2.98E-01,
4.50E-02,2.90E-01,
4.60E-02,2.83E-01,
4.70E-02,2.76E-01,
4.80E-02,2.70E-01,
4.90E-02,2.64E-01,
5.00E-02,2.58E-01,
5.10E-02,2.53E-01,
5.20E-02,2.49E-01,
5.30E-02,2.44E-01,
5.40E-02,2.40E-01,
5.50E-02,2.36E-01,
5.60E-02,2.33E-01,
5.70E-02,2.29E-01,
5.80E-02,2.26E-01,
5.90E-02,2.23E-01,
6.00E-02,2.20E-01,
6.10E-02,2.18E-01,
6.20E-02,2.15E-01,
6.30E-02,2.13E-01,
6.40E-02,2.11E-01,
6.50E-02,2.08E-01,
2.50E-01,1.21E-01,
2.60E-01,1.19E-01,
2.80E-01,1.16E-01,
3.00E-01,1.13E-01,
3.20E-01,1.10E-01,
3.40E-01,1.08E-01,
3.60E-01,1.05E-01,
3.80E-01,1.03E-01,
4.00E-01,1.01E-01,
4.20E-01,9.91E-02,
4.40E-01,9.72E-02,
4.60E-01,9.54E-02,
4.80E-01,9.38E-02,
5.00E-01,9.22E-02,
5.50E-01,8.85E-02,
6.00E-01,8.52E-02,
6.50E-01,8.22E-02,
7.00E-01,7.95E-02,
7.50E-01,7.71E-02,
8.00E-01,7.48E-02,
8.50E-01,7.27E-02,
9.00E-01,7.07E-02,
9.50E-01,6.89E-02,
1.00E+00,6.72E-02,
2.00E+00,4.70E-02,
3.00E+00,3.78E-02,
4.00E+00,3.25E-02,
5.00E+00,2.90E-02,
6.00E+00,2.65E-02,
7.00E+00,2.47E-02,
8.00E+00,2.33E-02,
9.00E+00,2.23E-02,
1.00E+01,2.14E-02,
1.10E+01,2.07E-02,
1.20E+01,2.01E-02,
1.30E+01,1.96E-02,
1.40E+01,1.92E-02,
1.50E+01,1.88E-02,
1.60E+01,1.85E-02,
1.70E+01,1.83E-02,
1.80E+01,1.80E-02,
1.90E+01,1.78E-02,
2.00E+01,1.77E-02,
]

energies = np.array([1,1.5,2,3,4,5,6,8,10,15,20,30,40,50,60,80,100,150,200,300,400,500,600,800,1000,1250,1500,2000,3000,4000,5000,6000,8000,10000,15000,20000])
vals2 = [3721.8066,1219.5075,539.38653,198.63231,450.86814,395.0083,181.03761,97.722264,58.646478,25.904221,13.687113,4.3420154,2.0018766,0.78211966,0.47879593,0.36613043,0.31250897,0.26264519,0.23817196,0.20570829,0.18618718,0.16069475,0.14365192,0.13105975,0.12114408,0.10635685,0.095598529,0.085493013,0.0778224,0.066823015,0.05374324,0.046144933,0.041174639,0.037689921,0.033147661,0.030371173,0.026723241,0.025070316
];

# %%
plt.figure()
plt.loglog(vals[::2],vals[1::2])
plt.loglog(energies[:]/1000,np.array(vals2[2:])/1.42)
# plt.loglog(energies[10:]/1000,np.exp(atten_small))
# plt.loglog(energies[3:]/1000,Cl[5:])
# plt.loglog(energies[10:]/1000,C[10:])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
H = np.array([0.00060442375,0.000179895,8.869125E-05,4.70005E-05,3.807275E-05,3.5116375E-05,3.385175E-05,3.277975E-05,3.227725E-05,3.15235E-05,3.0945625E-05,2.989875E-05,2.896075E-05,2.8098125E-05,2.73025E-05,2.5887125E-05,2.4656E-05,2.2202125E-05,2.0342875E-05,1.7688E-05,1.5853875E-05,1.4480375E-05,1.3391625E-05,1.1766875E-05,1.0577625E-05,9.455375E-06,8.601125E-06,7.3440375E-06,5.7963375E-06,4.862525E-06,4.2285375E-06,3.767075E-06,3.137275E-06,2.725225E-06,2.1264125E-06,1.8031375E-06
])
C = np.array([3758.7,1190.34,514.42,153.561,64.226,32.504,18.615,7.7792,4.0341,1.37207,0.7514,0.43554,0.35292,0.31807,0.29801,0.2737,0.25738,0.22899,0.20893,0.18122,0.162282,0.148155,0.136986,0.120292,0.108137,0.09673,0.088043,0.075514,0.060554,0.051799,0.046036,0.041973,0.036618,0.033303,0.028866,0.026775
])
O = np.array([6.11388,2.063268,0.9256068,0.2891772,0.1240758,0.0638028,0.0368964,0.01549116,0.007928064,0.002445552,0.0011523132,0.0005033628,0.000344322,0.0002839824,0.0002540124,0.0002235096,0.0002065932,0.0001812852,0.0001647684,0.000142524,0.00012741912,0.00011627028,0.0001074924,9.439884E-05,8.487504E-05,7.588404E-05,6.90642E-05,5.939388E-05,4.791204E-05,4.1292E-05,3.698964E-05,3.399264E-05,3.014316E-05,2.782548E-05,2.485512E-05,2.35764E-05
])
Cl = np.array([8.48184,2.9264145,1.35374,0.531313,4.902815,4.411635,2.1075815,1.1683495,0.714008,0.3219625,0.17146375,0.0534308,0.023178305,0.007262875,0.003345415,0.0019416585,0.0013163025,0.000807452,0.000613975,0.00044326,0.000379167,0.000315673,0.00027886445,0.00025316735,0.00023346025,0.0002044387,0.0001835336,0.0001640661,0.0001495703,0.0001296236,0.00010737075,9.54806E-05,8.83525E-05,8.38001E-05,7.87086E-05,7.634255E-05,7.47552E-05,7.5474E-05
])

H /= 8.375e-05
C /= 1.7
O /= 0.001332
Cl/= 0.002995

atten_small = np.interp(energies[10:]/1000,vals[::2],np.log(vals[1::2]))

def fun_atten(a):
    
    return np.mean(np.abs(np.exp(atten_small) - (H[10:]*a[0]+C[10:]*a[1]+O[10:]*a[2]+Cl[12:]*a[3])))

cons = ({'type': 'eq', 'fun': lambda x:  x[0] + x[1] + x[2] + x[3] - 1})
                   
bnds = ((0.05, 0.8), (0.1, 0.8), (0, 0.2), (0,0.2))

res = minimize(fun_atten, [0.1, 0.1, 0.7, 0.1], method='SLSQP', bounds=bnds,
               constraints=cons)    

a = res.x
print(a)
plt.figure()
plt.loglog(energies[10:],np.exp(atten_small))
plt.loglog(energies[10:],(H[10:]*a[0]+C[10:]*a[1]+O[10:]*a[2]+Cl[12:]*a[3]))
plt.loglog(energies[10:],H[10:])
plt.loglog(energies[10:],C[10:])

sum([0.0634, 0.6156, 0.1993, 0.1217])

reses = []
for ii in range(10000):

    reses.append(minimize(fun_zeff,[np.random.randint(0,20),np.random.randint(0,20),np.random.randint(0,20)],bounds=((0,20),(0,20),(0,20))).x)
# Out:
# [0.06333811 0.61559452 0.19933533 0.12173204]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# /home/xcite/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in double_scalars
