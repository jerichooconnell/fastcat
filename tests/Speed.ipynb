# %% [markdown]
# 479.310000s/1000000 for the detector simulations for one slice
# 27.860000s/1000000 for the phantom simulations for one slice
# 39.9s/ 360 512x512x10 360 fastCAT
# 61.1s/360 1024x1024x10 360 fastCAT

# %%
# %pylab nbagg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
nphot = 360*1e9

dat = [489/1000000*nphot,27.86/1000000*nphot,61.1,39.9]


plt.figure(figsize=[4,4],dpi=300)
plt.semilogy(dat,'k*')
plt.grid()
plt.ylabel('log compute time [core s]')
plt.xticks([0,1,2,3],labels=['full detector*','fastEPID*','fastCAT 1024$^2$x10','fastCAT 512$^2$x10'],rotation= 45)
plt.yticks([60,60*60,60*60*24,60*60*24*30,60*60*24*365],['minute','hour','day','month','year'])
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1199.3">

# %%
dat/()
# Out:
# [176040000.0, 10029600.0, 61.1, 39.9]

# %%
plt.savefig('/home/xcite/fastcat_paper/figures/times.pdf')

# %%
(27.86/1000000*nphot)/60
# Out:
# 167160.0
